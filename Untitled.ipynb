# %%
import torch
import pandas as pd
import numpy as np
import os
from dataloader import data_split,onehot, SongData
from models import GenLSTM
from configs import cfg

# %%
# Load the state_dict of a model given path
def load_model(path):
    
    # Make a fresh model
    model = GenLSTM(input_size = len(SongData.vocab), output_size = len(SongData.vocab))
    
    # Load in saved model params at checkpoint path
    model.load_state_dict(torch.load(path))
    
    return model

# Takes a pre-trained model and generate new text
def generateText(data, model, temp, num_samples, max_len):
    
    # Number of texts to generate
    # Max length of text
    numText = num_samples
    maxLen = max_len
    
    # Start the sentence with the SOS ordinal, ordinal value is 0
    # One-hot the values for generation
    text = torch.tensor(np.zeros((numText, 1))).long()
    
    EOSreached = False
    currSeqIndex = 0
    hc = None
    Temp = temp
    
    model.to(device)
    
    # Put into eval mode
    model.eval()
    
    # No need for gradient
    with torch.no_grad():
        
        # While we haven't reached the EOS run latest character through model with the previous hidden and cell state
        # Softmax and sample output and use that as input
        while (not EOSreached and currSeqIndex < maxLen):
            
            # Onehot the batch at the current sequence index
            oh_input = onehot(text[:,currSeqIndex:currSeqIndex+1], len(data.encode))
            oh_input = oh_input.to(device)
            
            # Pass characters at current sequence index through model
            # First character we don't have hc
            if not hc:
                output, hc = model(oh_input)
            # Every subsequent character we pass in the previous hc
            else:
                output, hc = model(oh_input, hc)
                
            # Convert outputs to probabilities using softmax with temperature
            probs = torch.nn.functional.softmax(output/Temp, dim=2)
            
            # Create distribution and sample for the next indices
            sampled = torch.distributions.categorical.Categorical(probs).sample()
            
            # Join sample with the current body of characters
            text = torch.cat((text, sampled.cpu()), dim=1)
            
            currSeqIndex += 1
            
            # Check whether each rows contain any 1s(EOS) and that must be true for all rows
            if (np.array(text) == 1).any(axis=1).all():
                EOSreached = True
                
    # Decode the ordinals to characters
    generated = [''.join([data.decode[c] for c in gen]) for gen in np.array(text)]
    
    # For each string remove everything after the first EOS(\3) and remove all SOS(\2)
    generated = [text[0:text.find('\3')+1].replace('\2','') if text.find('\3') > 0 else text.replace('\2','') 
                 for text in generated]
    
    print("Finished text generation...", flush=True)
    
    return generated

if __name__ == "__main__":

    # Parse arguments
    temp = 0.8
    num_samples = 10
    max_len = 5000
    
    
    print("Loading necessary files to generate...", flush=True)
    # Get dataset to know meta-data
    data = pd.read_csv('songdata.csv')
    SongData.init_vocab(data)
    train_set, val_set = data_split(data)
    
    # Get path
    checkpointPath = 'model_checkpoints/training_session0/'
    savedModePath = 'LSTMmodel_Final.fnl'
    
    # Load in trained model
    model = load_model(os.path.join(checkpointPath, savedModePath))
    
    useCuda = cfg['use_cuda']
    # Check for cuda and set default compute device
    if ( torch.cuda.is_available() and useCuda ):
        device = torch.device("cuda")

    else:
        device = torch.device("cpu")

    print("Using %s for compute..." % device.type, flush=True)
    
    
    print("Beginning text generation...", flush=True)
    
    # Generate text
    gen = generateText(train_set, model, temp, num_samples, max_len)
    
    # Write out generated texts into result file
    resultPath = "./results/"
    resultFile = "generatedsamples_temp_{0}".format(temp)
    
    for idx, text in enumerate(gen):
        print(text, flush=True)
        print("---------------", flush=True)
# Out:
# Loading necessary files to generate...
# Using cuda for compute...
# Beginning text generation...
# Finished text generation...
# Here we go in the sky
# But he says it's the feeling that's always too late
#
# What about me.
# How to do you win
# Love is the things that would be strong
# She ain't got no nails
# We'll spare her shoot is strange
# Holding on to the back
#
# So he meats the dreams
# Drive in angels the heat
# He matters the woman is the way
# She was denying good
# Where the heat of love
# I know when I think
# I am more of him
# He likes a loving could help it
# And the guiltary to her
# (People was a chance)
#
# (Chorus)
#
# Chorus
#
# The changesh end
#
# Of a corner little mishol of from my soul
# Because you breathe free
# I really have to find me
# Take dish now
# And you cry
# I wonder what to do
#
# I'll be sure you work as made
# For ask me the land
# Kill of winter my said
# While closer, flesh
# I will surrender then I haven't better
# I wish I was standin'
#
# This is a long ride
# But it said I touch you
# And I don't know where you're the way
# What I do with the star
#
# [Chorus]
# All the time that she's gone
# I'm not blind
# My seasons world has told
# They call me back
# I love you, have a little fancy
# And say I'm falling over
# My eyes are gonna mind
# It was dreaming
# I can't be sure
# And I found anything
#
# Verse 3:
# I don't know what I will
# I'm there lonely
# I give some muled
# As I shine around
# And I've got a tree
# I want you to say
# in the place for crazy
# When I'm staying
# I can't even come to
# But you brought me on the blocked your very place
# You'll fall in love
# You mama am a million bilowet
# Looking at my baby are pointing
# I cast the ground made
# You can be, I went when I could listen
#
# If I should know I can't see you just
# There's somebody to winter
# You know the way it ever could fly
# I've been the complain
#
# I don't know what I hold through
# Each rock
# I hold nobody be your paradise
#
# You might be the boys that I love the biffectious
# I would be the Hanger
#
# Blue out the ence on my view
#
# And tell the bride
# I was gonna guite and not the way
# The morning thing I do as was I ask
# Yeah
# When I hope you'll be from spinning
# And what a day
# Yes I do, I do
# My heart was high
# I was such the skin
# Blood on me
# I can't start to let her
# Boy I wonder who these for
#
# Noomorrof are I'm coming
# The party was so tasted
# Stay
#
# I just don't know what I don't
# It's the tear
# Sometimes I say the hoes
# I want to be fired
#
# I'm always all my love
# I was beautiful life
#
# And it's alive
# And I want fun
#
# So I want to from it
# Alone and my hair
# Who's like a bitter
# I realized and I don't like the day
# That I miss you how I can
# Only be in the light
# You miss me
# I want from my ear
# The purses march the perfect
# Strange at me and you
#
# And the morning searly at all
# This will come to the way
# On the top days
# With my intropation
# I drown over your eyes
#
# I love the morning soul
# I moved and then I'm left for me
# I don't want to shoot me signing
# I'm the morning clouds
# I see you life at miles
# That down in my hands
# I was the last thing I follow
# The same love
# I can't go of this song
# And I want to see you
# I'm not true
# I sure I can want no more
# And I finally slow
#
#
# ---------------
# I better come good but I don't know how
# Up and turn on your castle like a holy day
# Got a pass is my baby
# Every disco a making more saving
# And I was alright
# You can go
# I wanna be alone
# And you don't want to know, that I'm here
#
# She's all I want again, you got something to see me
# La than why I should have opened on the chance
# So I got something that it's a boy, what's the game
# And a ground play the old moon that I cannot make it to me,
# I have only dark I have to faced in the world
# They're too late to get along and I know I was better tonight
#
# [Chorus]
# (I'm in all the woman is my dark-believe)
# And I'm just so hard in love
# I cannot hold on to forget
#
# Don't go to the telephone
# I'm a be the moon
# I don't even mate it so say
# So how I'm mine
# So here if I don't have the way
#
# Yes I really had
# I can't take it again
#
# [Chorus]
# For you are alone
# Bye out of my mind
# I can't stay dark baby, I couldn't feel like this
# tell me, baby oh, oh
# You don't ever go
# It's a little long hot
#
# Can't resist your heart
# No I'm so dangerous
# And I will be there anything about how to say
#
# [Chorus]
# Whoa know I find a fucking other
# And I can say nothing out there
# Now anymore you've been
# And I won't have a little little smile
# May be yours to take me a little bit of down
# But you don't mean
#
# I want to be true in my girl
#
# Let's think about
# When my body felt it spain
# I don't want to be too to you
# This is hard to know
# Cause I just been gone
#
# [Chorus]
#
# Don't take me alone
# But I'm gonna get their sins
# I really just a chick up in the world
# I want to say my wife got me down
# I want to know what I want
# I wish I would never see the surprise
# I've been changing ain't the chance
# Yeah, I'm gonna find a real man who makes a dirty day
#
# Be wide to be, I'm so hard to go
#
# Every body do it obfore
# That I should fucinver
# I think I can run on the realuro
# I want to lend you on the mirror
# And our fare of the story
# Oh gog on the end of the walls
# And what makes me feel god
# I need enour and they hold him
# There's a clock in all
# So bad the way that they brought me
# That it was home
# And if you're in the rakes
#
# I'll get a part of what I love you
# I know that I'm found all with you
# I'm the one that things that I got
# I know I don't know what I'm gained
# I'm going to make you to walk and watch my mother
# I wanna make
# I'm a mother so why
#
# No more to love
# I was worth
# She insterfic my head
# I won't be on the start to go
#
# Shoot me ah
#
# I thank you
# I found my lead
# Living in Melogara
# And I won't be right
# And I'm calling my heart
# They make me feel so much
# I got to the sand
# I know you were clouds
# I can stay and tell me
#
# I remember I don't need
# But I don't take her over
#
# So I shouldn't start to
# I am my life now
# Dream that I ever need
# But something but I said
# I want to say goodbye
# And be such a stone
# I will say goodbye (yeah)
# She's got an arms
# And my heart
# Should I have another shit,
# I know I said something goes
# That I know I said
# That I can be
# I'm dead
# Baby (I'm lonesite)
# I got my sunk of siguison
# I won't lie with me (I don't know what)
#
#
# ---------------
# Maybe a little morning
# You know you'll fall your arms I need
#
# Going to hold on the past
# The war drinking inside
# I know that I might be leaving
# To hide an baths give me suffer
# When the night time I ended on the shake
# For your soul words and a fool
# I don't want to be a must want
# When the lonely I'll guide
# Cause I don't want to walk away
# And I'm sinced you back in the silence
# I know I haven't passed my mind
# And I won't pay the floor blind
# I won't remember, I think I'm not formise
# It was percamena you
# I don't know what to think I do
# The word's only only inside my soul
#
#
# ---------------
# Meeriame you
#
# And oh you will never lie
# If you believe is something
# I want to keep you until myself
# Right all you know
#
# All my friends you're more
# And I'll be danger, pain as well
#
# We're the people that we have a like
# I feel the way you don't get this suddenly knows
# You're it good and all I want to be
# You can fall in love with you
#
# I think you've been started by the money
# Why you sit and I forgive me
#
# Why don't you want me friend
# I have she leaves me
# Don't let me is what I love to see
# Oh, help me home
# I need a little flows all too dessers
# I had to make you go, no
# I can't win of my mind
#
# I see the was day above
# A place I know what I'm always
# All the ladds to be
#
# I keep thinking I don't leatn to leave my life
# I feel like you'll be bright all around
# I'd rather know that you're lately
# I said without a see the lonely hame
# No time for you
# You don't belong the love
# I found out of love
# I don't know what I'm stronger?
# I just got the same with, oh
# And I see your love
# Why don't you moment on my heart
# What's the night
# Everybody needs a little bit of my life
#
# [Chorus]
# ---------------
# Yeah evening me for me
#
# A mirror in a straighty spell
# For left to make uh lovers
# Roll to the door of me
# Run to the last car
#
# 1941
# I dream of your hand
# Ambongian will crack
# Who are a three
# Heartbeat you
# (Give me the way and open the air
# He's the aninats
# My heart is gathered
# (Ah hey)
# He's in the way hard
# He ain't gonna girl
# That they're still the moon
# But we got a too
# So come
# We but know what he begins
#
# Then the ends me in the blues
# My horses don't have been running
# But he was the mission
#
# Gather with her list to crawl
# He's a ringing dishine
# They'll be the being are cold
# We don't change to the world
# Yes I sit by one
#
# Today, what you going
#
# Tell me what they don't make this
# Just keep gonna dropped me a milly
#
# I don't wanna see you goin
# I'll break the money
# And if you took the world
# Echoluate
# I only hear that
# I may it running out of Merrack
# I got the woods
# Until the same
# Death who cares
# First, they said
# They were baby
# We will forget out here
# I'm for a sun of girl
# He got where they sing out
# I say now
#
# [Chorus]
# And the time it used to be burning
# But I don't know about the best of the sky
# I wish that she's the tree
#
# I bought my way of my morning
# I would make in
#
# Wash the rippes through the night, woman with me to
# I'm just living what I ever should know
# Though I want to stay to me
#
# And I'm out of love and myself
# I see my disasse
# I loved you
# I don't make a war
# You were meaned to hold you
# Look around
#
# Everyday I don't want to do
# What can I go on
# I can't talk often their breed
# Like you've seen
# A little haboluttally
# I want something now
#
# No one protectime
# I just what you can't live
# You will love me
# I want to be alone
# I never gonna go
# When I'm gonna all make love as I need
#
# Sung me down
#
# I'm assoning like me
# I got the sun
# I'm lacked around
# I'm the only one life
# It's a pain
# So this gangshaps
#
# I'm again
# I've got a river
# With a heartlessed spine
# And I can charce the winter
# I said I'm showing
# They've got to do what you're lost
# All I've done no
# I want to fill you
# It's all for me
# I'll get crying
# I want you to stay
# I got the seeing the days of good
# I'm not reason
#
# I'm the one that I'm going to see
# I'm parking down along
# I could get hurts
# I can't even feel the sand that I mean
# You can resist I
#
# I never ask of the fire
# I look away
# I don't want power to tell
# I can't go or in the morning
# I don't need to know
# I want to see you
# So fallin' on a little answer
#
# I'm dreaming of a while
# I would come waste for you
# And I just wanna think I'll my while
# I see the passing down the round
# I don't want a poured and before
# I don't need to take the country and you
# Suternation and I'm in the dark
# I was good I'm going to proud you
#
# I feel for her I want to be so long
# And I'm gonna be a minute
# I'll get inside that I drive
# 'Cause I was there it through
#
# I want my own town
# You can't exprate me
# I can see the same and I to turn my heart
# Yes I got to watch me to
# I really ever feel
#
# Can you lay
# I'll see good perfect pulled hand
# I'm a way from way baby
# I'm saying that I miss you
#
# You can't still forgottin'
# You can do this a memonicy
# I've been a wrong can't fair
#
# I don't know as I only want it
# I'm just give a dours alone
# I'm so lowing on down
# I'll be because I'm looking on the window
# I've got me for you
# I been a broken to you, I'm such a killer
# I'm gonna be well to hell my girl
# I'm still and tonight
# I got the kind of never too lose
#
# I just wanna do you truck me
# I said I'm goin' on the night
# I want to be but I don't want to be right
# I'll be the love that I'm all about you
# I want you to say though
# It's over away
# I feel like I'm watching you
#
# I want to break my heart
#
# Yeah, I'm not to be
# On the price of your chess
# Your suffering yeah
# You don't feel your bones
# I'm not sure when you bitter played some
#
# Cause I want you with my heart
# What you're in a gave
# That love is too long
# Or a star, I'm so alone
# Oh baby, I know you
# I won't die
# I don't want to love
#
# Oh, I got no ohe soul
# What you got none of thinkin'
# I need you
# If they matter where you got me
# Don't make me go
#
# Since I should do when the people
#
# You're on the line of my setter
# I hope you're more than think yeah
# I won't feel right
#
# I'm the one I keep thinking
# That I want to love you
# I'm my crazy
# I'm in the fight
# I'relieved on, in this time
# I know what I want I can't tell
# My mama knows
# I want you for girl
# I don't understand, I think of me
#
# Come on out of this
# Alright
# I'm going to be caught up
# There's an angel
# And I've made my price
# I wanna dark
# I remember I'll be the one
#
# [Chorus]
# All I've got to pay the raity tonight
# Oh no
# If you want me to peace
# And I got our old friends with.
# ---------------
# And even you want to put my dark
# The girls are learning and a pain of the end
# That's what it's alright
# And I'm like and I'm singing for no one of my money
# Yes I say for you
# With the bearshed of the same
# My faith's kind of mind that was a pression is all
# I'm hope, I sit just a trace and the story may has been true
#
# I won't buy this in any on you
# I used to knyw you can let me free
# I'm so good to be the one I can't get a better
# And that made it have a dronk and
# I am shattered for me
#
# I can perfect the blues, I was word
# I got the mind
# Waste the mind I can play all the real big
# I think I won't be so world
# I sure that I can't explode
# You say In that of the bear of the day
# And there's nothing alled
# Nothing that is not you
# I can't stay that falls to this
#
# I want to tell you of my mother
# And all the eye toder
# So you think then I swear
# And the morning has shines
# But I don't be alone
# I wish I am the same
# As it made if I always do
# But I fly away
# I wish I hear the man I can see
# I need you to hide
# To help me
# And I'm gonna make him
#
# When I love you
# I don't know
#
# Oh oh
# Makes you better
# You've broked me
# Oh
# 'cause I want you
# Oh baby
# It's all to you
# I will fall
# Anytime you
#
#
# ---------------
# She's can save my mother hand
# What a pair that I didn't know
# When I'm done now she made me last
# I don't have to give me down to a sell
# My guider man against the single from the corner
# War or willing to tell roll
# Don't you know it
#
# No cut the sugar silent light
# Free out, on the highway
# Mulizing, drinking music all my mind,
# I see the way free more and I'm right,
# What to go long
# I'd give a man
# I missed any way home
# I will steal our words
# I will lies, just a lonely hood on
# I know what I love your broken.
# Lose of all the stars are has been
# My paradise
#
# I want to have you, I would never take anything alone
# The blue enough
# I see the way that I feel like insane
#
# The sun goes around the wire
# I was strocked to all then, I put you dry
# He liked the rainion man of Green
# I didn't do what I had to go
# But I surprise"
#
# Please for two on the rivers
# I ain't talking to waste
# I really was dreaming
# So don't let it game
#
# I look to love
# That I was burning to fill
#
# I drink and the sea to something I say
# But I don't wanna see you with me
# Makes me feel lying
# All you make a blood made me
# I went to the sheleful just chozing
#
# I might play it up, my lover with the morning
# And I stay always knowing stretted to me
# Shall have you had for another
# The cross what a fingers there is so good to say
# And you believe me
# And I could love you or her eyes
# I'll never see you
# And I don't cover the sound of my side
# I could closh this world and born's reasons
# And happen so the same without you
#
# Who have called me to put you away
# And you are white walking through
# We would lay out of here
# She's just a bellen, no torm
# In a broken on the stars
# There and me, I went a car
#
# You got the evening add a voice I want to see
# All I saw you most kiss
# Knowing that I never hear
# In the rain that you will have my heart
# We cry
# She might find my heart
#
# I dream a little obve
# My guns of my south
# Don't turn any trip of dear
# No song
# And the pain of my mind
# Has a rest of my hands
# I have stood easy
# I was
# I wanna know, baby
# Do I feel about me
# I, I will pretend to me
#
# I want to together
# I can so say,
# I can last though I'm the night
# At the years for how I'm so anyway
# Oh I can't feel me
# And I wanna do
# So what I mean
# I got to give me cause I am a brand now
#
# I hope I had a lit about the didn't walk
# But I can't help something
# Now it's more than the ones
# They can't live what about
#
#
# When I'm blind in pieces
# I do
# (No big walking)
# I want to be my own
# I believe, I can't wait
# And I want you?
# I can't stay
# I win
# I want me what I touch?
# I don't know why, it's the way
# I got the sound of you
# I want to take you and I will not tell you
# I just want you
# I tried it on the century
# I'm not the one that I told
# I got the world where I found
# I'm a little figure
# I'm colding another build
# Don't let me try to get too people
# Come on baby
# Baby baby I'm makin'
# But I'm right what I need
# I'm gonna love you more
# I'm so truth you'll get my blues
# I gotta unipand
# What am I'm gonna come
# I know I'm gonna stay
# Sun if it's all
# I can't take you try
# He can see the wind
# You got burned gap
# To the door all around
# I can't side the way
# ---------------
# I got to fight all the stars
# You can chainfuses at your tears
# That you love me
# To make love
#
# Oh puble the Lord
# So the moment to me
# To tar what I mean
# And I don't want to
# And it's time we want to go
# I'm alone
# It came to say
# And I'm gonna take the other
# And I can't turn things
# I ran a treat like the boy
# I want to see me good
# The party was a wanted beg't look back
# It's the good bunnun
# You can't see the day ain't so body
# Why don't you promise
# I've got the darker
# I'll be better than keep on calling me
# People try to be free
# You take my life
#
# [Chorus]
#
# I got one so if I say
# So I got the same me in the night
# And I don't know she says I
# I got my heart is back
# And I'm just, 'til I do
# Oh, you see her six shame
# I can do it?
#
# [Chorus]
#
#
# ---------------
# The morning streets I fall to through the way
# I kiss you tomorrow so he could have been still
# I never know like I don't know why
# Spend drink back the sheets without behind
# When they ain't gonna rime to the street
# I don't have a pole hours there
# I don't want there I got here to go
# When I see her are some knight
#
# You know I neadly see the fire in the day
# The obbitions of everything like the eyes
# From all the wrong show no other light
# I can feel like this song you deep inside
# I love you unbeled up from here
# Walking for your bands that summer black
# The clouds must I know
# I'm not calling my eyoud
#
# I was lost it's geined oon ayound it
# I want to be now who shade
# I don't care
# If we don't know the sun as outside
# The only one's change
# And I ever filled the devil
# They take me that burns
# I ain't got her so don't be someone down
#
# Now I've been in my darkness
# And the ground this one light
# Whoa whoa oh
# All the way you start to keep
# When I burn the blue
# And I should're down
#
# With your mind
# That's the sky in the hater
# The pretty step in the chance
# I got the way that it feels
# To hold you hang in
#
# Hey command
# You can see it out till the spin
# And it's the trees of my love
#
# You went high
# High and we don't know
# where do the other day
#
# Oh baby 'cause I love you
# What they say what about the good thing and fall
# And realized of the embrace
# It's the clouds
#
# Hearware goodness
# How can I thank the sky
# Don't let it be
# I can't keep me harders
#
# And I can't deny
# I love to forget how
# I wanna see
# Well just be in a door
# Who is the finer
# And I gave you friend
# I know you want me
# I tell me what I am
#
# Well if you till the counts
#
# Now I feel like that
# It feels so flowing
# The capagan's pain
# If love will hear it
# Ooh
#
# Beat my eyes
# So good
# All along
# Take my eyes
# This good
# I don't care if you just don't know
# Let me blue me
# So what I used to feel you for
# I'm the forever
# And for you
#
# I'm the sun get with me
# I'm living in my way
# I gatel my life has gone
#
# Love my name of my mind
# It seem to fly
# I'm so play
# I'm gonna take you
# The man wind
#
# But I'm been goin'
# Oh you put me wrlack and dream
#
# It's all the words
# I got change
# I really always love you
# I'm gonna be the other
#
# I see the board street I've been my life
# All I need a little thing
# You better cry out
#
# Here I feel this said
# And I want to you
#
# I wanna be there
# I won't get him much
# I know it as sunshine
# I can't hear a job I know
#
# I can belong to me
#
#
# ---------------
# [Chorus]
# Day you need me
# Will you.
#
# You are the power of the sparks
# It's all falling from your loving just like the band
# True where I hear the minds I can't feel that the from the smiles
# When I am and walking within the night of the rain
# So lonely nother to hide and tear and come and I rescue
# You'll be here are the arms of the top of you
#
#
# ---------------
